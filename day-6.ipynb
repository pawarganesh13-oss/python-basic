# %%
a='python'+'java'

# %%
a
# Out:
# 'pythonjava'

# %%
len(a)
# Out:
# 10

# %%
'python'*7
# Out:
# 'pythonpythonpythonpythonpythonpythonpython'

# %%
a.find('a')         #indexing number of a in string
                    #a.+tab Button->show built in function
# Out:
# 7

# %%
a.find('i')             #if find i not found in string then show -1
# Out:
# -1

# %%
a.find('y')            #indexing number of y in string
# Out:
# 1

# %%
a.find('python')
# Out:
# 0

# %%
a
# Out:
# 'pythonjava'

# %%
a.count('a')            #how many time 'a' present in string
# Out:
# 2

# %%
a.count('p')             #how many time 'p' present in string
# Out:
# 1

# %%
a.count('j')
# Out:
# 1

# %%
a.count('x')          #if count is not present in string then show 0
# Out:
# 0

# %%
a
# Out:
# 'pythonjava'

# %%
a.split()            #Use for splite sring base on charachter
# Out:
# ['pythonjava']

# %%
a.split('n')              #base on 'n' character split string
# Out:
# ['pytho', 'java']

# %%
b='python java'

# %%
b
# Out:
# 'python java'

# %%
b.split()                  #base on ' ' split string
# Out:
# ['python', 'java']

# %%
type(a.split())             #find type of a.split()
# Out:
# list

# %%
l=a.split()

# %%
l
# Out:
# ['pythonjava']

# %%
b.split()
# Out:
# ['python', 'java']

# %%
b[0]
# Out:
# 'p'

# %%
b[1]
# Out:
# 'y'

# %%
b[2]
# Out:
# 't'

# %%
b[3]
# Out:
# 'h'

# %%
b[4]
# Out:
# 'o'

# %%
b[5]
# Out:
# 'n'

# %%
b[6]
# Out:
# ' '

# %%
a='pythonjava'

# %%
a.split('a')     #split("a") breaks the string wherever character a is found and returns result in li
# Out:
# ['pythonj', 'v', '']

# %%
a.split(a[7])
# Out:
# ['pythonj', 'v', '']

# %%
a.split(a[9])
# Out:
# ['pythonj', 'v', '']

# %%
a[0:3]
# Out:
# 'pyt'

# %%
a
# Out:
# 'pythonjava'

# %%
a[1]
# Out:
# ','

# %%
a='python'
a="python"
a='2,3,4,5,6'

# %%
type(a)
# Out:
# str

# %%
_a=345     #variable declaration

# %%
_a
# Out:
# 345

# %%
*a=1234
# Out:
#   File "<ipython-input-53-22a2f0b9a594>", line 4
# SyntaxError: starred assignment target must be in a list or tuple

# %%
123a=123
# Out:
#   File "<ipython-input-54-8e354e5c8909>", line 1
#     123a=123
#        ^
# SyntaxError: invalid syntax

# %%
$345a=123
# Out:
#   File "<ipython-input-55-d1a783333dbb>", line 1
#     $345a=123
#     ^
# SyntaxError: invalid syntax
