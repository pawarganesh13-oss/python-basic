# %%
a='i am working with google'

# %%
a
# Out:
# 'i am working with google'

# %%
a.split(' ')   #splite basis on  ' '
# Out:
# ['i', 'am', 'working', 'with', 'google']

# %%
a.split('w')  #splite basis on  'w' char
# Out:
# ['i am ', 'orking ', 'ith google']

# %%
a.split('wo')
# Out:
# ['i am ', 'rking with google']

# %%
a.upper()         #inbuilt function for convert uppercase
# Out:
# 'I AM WORKING WITH GOOGLE'

# %%
a='mltr'

# %%
a.upper()
# Out:
# 'MLTR'

# %%
a.swapcase()                #converted into upposite case ,a='mltr' => 'MLTR' vice versa
# Out:
# 'MLTR'

# %%
a.title()                   #It converts the first letter of each word into capital letter.
# Out:
# 'Mltr'

# %%
a.capitalize()              #title() capitalizes each word, but capitalize() capitalizes only first letter of full sentence.
# Out:
# 'Mltr'

# %%
b='mlrt'
c='goonline'                #b.join(c) means join all characters of c by using b as separator.
b.join(c)
# Out:
# 'gmlrtomlrtomlrtnmlrtlmlrtimlrtnmlrte'

# %%
' '.join('mlrt')
# Out:
# 'm l r t'

# %%
reversed("mlrt")

# %%
for i in reversed("mlrt"):
    print(i)
# Out:
# t
# r
# l
# m

# %%
a="mlrt"
a[::-1]
# Out:
# 'trlm'

# %%
m="mlrt"

# %%
m.rstrip()       #Removes spaces from right side only.
# Out:
# 'mlrt'

# %%
m.lstrip()       #Removes spaces from left side only.
# Out:
# 'mlrt'

# %%
m.strip()        #Removes spaces from both sides.
# Out:
# 'mlrt'

# %%
a = "   python   "

# %%
a.rstrip()
# Out:
# '   python'

# %%
a.lstrip()
# Out:
# 'python   '

# %%
a.strip()
# Out:
# 'python'

# %%
m="mlrt"
m.replace('l','abc')     #Find 'l' and replace it with 'abc'
                        #replace() does not change original string permanently.
# Out:
# 'mabcrt'

# %%
m.replace('a','lmk')      #if 'a' character not found in string then show origenal string 'mlrt'
# Out:
# 'mlrt'

# %%
"rama\tkrishna".expandtabs()      #expandtabs() is a string method used to replace tab characters \t with spaces.
# Out:
# 'rama    krishna'

# %%
"go\tonline\ttraining".expandtabs()
# Out:
# 'go      online  training'

# %%
m="mlrt"

# %%
m
# Out:
# 'mlrt'

# %%
m.center(40,'t')    #means keep m in center and fill remaining space with t until total length becomes.
# Out:
# 'ttttttttttttttttttmlrttttttttttttttttttt'

# %%
m.center(40,' ')     #means keep m in center and fill remaining space with ' ' until total length becomes.
# Out:
# '                  mlrt                  '

# %%
m.center(40,'teja')     #TypeError: The fill character must be exactly one character long,
                        #In center(), second parameter must be only one character, so 'teja' is invalid.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f3a0d1db5f70> in <module>
# ----> 1 m.center(40,'teja')     #TypeError: The fill character must be exactly one character long,
#       2                         #In center(), second parameter must be only one character, so 'teja' is invalid.
#
# NameError: name 'm' is not defined

# %%
b="indians are best in this world"
b.strip("are")
# Out:
# 'indians are best in this world'

# %%
b="          indians are best in this world    "
b.strip()
# Out:
# 'indians are best in this world'

# %%
b="mlrt"

# %%
b.isupper()    # isupper() checks whether all alphabet letters are uppercase or not.
               # True  → if all letters are uppercase
               # False → if letters are not uppercase
# Out:
# False

# %%
b="MLRT"
b.isupper()
# Out:
# True

# %%
b.islower()  #checks whether all alphabet letters are lowercase or not
# Out:
# False

# %%
b.isspace()   #isspace() checks whether string contains only whitespace
# Out:
# False

# %%
b="   mlrt"
b.isspace()
# Out:
# False

# %%
b="  "
b.isspace()
# Out:
# True

# %%
m="mlrt1234"

# %%
m.isdigit()     #isdigit() checks whether the string contains only digits/numbers.
# Out:
# False

# %%
m="1234"
m.isdigit()
# Out:
# True

# %%
m="python"

# %%
m.endswith('n')    # endswith() checks whether a string ends with given character or word.
# Out:
# True

# %%
m.endswith('a')
# Out:
# False

# %%
m.startswith('p')   # startswith() checks whether a string starts with given character or word
# Out:
# True

# %%
m.startswith('a')
# Out:
# False

# %%
m.istitle()        #Title case means every word’s first letter is capital.
# Out:
# False

# %%
m.encode()     #encode() converts string data into bytes format.
# Out:
# b'python'

# %%
#List--

# %%
#list is a collection of multiple homogeneous or hetrogeneous daa sets

# %%
l=["mlrt","ravi",345,123.45]             #hetrogeneous
r=[12,13,45,56,67]                       #homogeneous
type(l)
# Out:
# list

# %%
a="mlrt"
a[0]
# Out:
# 'm'

# %%
l[0]
# Out:
# 'mlrt'

# %%
r[0]
# Out:
# 12

# %%
l[-1]
# Out:
# 123.45

# %%
l[0:4]
# Out:
# ['mlrt', 'ravi', 345, 123.45]

# %%
l[::-1]
# Out:
# [123.45, 345, 'ravi', 'mlrt']

# %%
l[-1:6]
# Out:
# [123.45]

# %%
l[0]
# Out:
# 'mlrt'

# %%
l[0][1]
# Out:
# 'l'

# %%
l[1]
# Out:
# 'ravi'

# %%
l[1][3]              #find 'i' from 'ravi'
# Out:
# 'i'

# %%
l
# Out:
# ['mlrt', 'ravi', 345, 123.45]

# %%
l[-1:4:-1]
# Out:
# []
