# %%
l=[123,45.67,True,45+6j,'python']

# %%
type(l)
# Out:
# list

# %%
l[3]
# Out:
# (45+6j)

# %%
l[3].real
# Out:
# 45.0

# %%
l[3].imag
# Out:
# 6.0

# %%
l1=["mlrt","ravi",4445454]
l2=["abc","xyz",132424354567]

# %%
l1+l2                  #concatination of list possible
# Out:
# ['mlrt', 'ravi', 4445454, 'abc', 'xyz', 132424354567]

# %%
l1+'python'     #Python cannot directly join list + string.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-7ec840f4bd67> in <module>
# ----> 1 l1+'python'
#
# TypeError: can only concatenate list (not "str") to list

# %%
l1+['python']         #list concstinstion join possible
# Out:
# ['mlrt', 'ravi', 4445454, 'python']

# %%
l1
# Out:
# ['mlrt', 'ravi', 4445454]

# %%
l1 * 4             # means repeat the list 4 times.
# Out:
# ['mlrt',
#  'ravi',
#  4445454,
#  'mlrt',
#  'ravi',
#  4445454,
#  'mlrt',
#  'ravi',
#  4445454,
#  'mlrt',
#  'ravi',
#  4445454]

# %%
l1[0]
# Out:
# 'mlrt'

# %%
l1[0]="python"   #Update index 0 value with "python" insted of mlrt

# %%
l1
# Out:
# ['python', 'ravi', 4445454]

# %%
l1[0]=242353456456547567686787

# %%
l1
# Out:
# [242353456456547567686787, 'ravi', 4445454]

# %%
l1[1][0]="s"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-a61ac3c382ec> in <module>
# ----> 1 l1[1][0]="s"
#
# TypeError: 'str' object does not support item assignment

# %%
l1[1]
# Out:
# 'ravi'

# %%
a='true'
a[0]='a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-b27f77f02d85> in <module>
#       1 a='true'
# ----> 2 a[0]='a'
#
# TypeError: 'str' object does not support item assignment

# %%
a.replace('t','a')
# Out:
# 'arue'

# %%
l1
# Out:
# [242353456456547567686787, 'ravi', 4445454]

# %%
'ravi' in l1    #'ravi' in l1 checks whether 'ravi' exists inside list l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1c6ddff692d9> in <module>
# ----> 1 'ravi' in l1    #'ravi' in l1 checks whether 'ravi' exists inside list l1
#
# NameError: name 'l1' is not defined

# %%
12376 in l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-af2afb6e44b8> in <module>
# ----> 1 12376 in l1
#
# NameError: name 'l1' is not defined

# %%
l2
# Out:
# ['abc', 'xyz', 132424354567]

# %%
l2.append('sql')             #adds 'sql' as a single element at the end of the list.

# %%
l2
# Out:
# ['abc', 'xyz', 132424354567, 'sql', 'sql', 'sql']

# %%
l2.append('machinelearning')

# %%
l2
# Out:
# ['abc', 'xyz', 132424354567, 'sql', 'sql', 'sql', 'machinelearning']

# %%
l2.pop()                      #removes the last value from list.
# Out:
# 'machinelearning'

# %%
l2
# Out:
# ['abc', 'xyz', 132424354567, 'sql', 'sql', 'sql']

# %%
l2.pop(2)    #removes value from index 2.
# Out:
# 132424354567

# %%
l2.append(2324234235)    #move perticular index in last then append and index

# %%
l2
# Out:
# ['abc', 'xyz', 'sql', 'sql', 'sql', 2324234235]

# %%
l2.pop(2)
# Out:
# 'sql'

# %%
l2
# Out:
# ['abc', 'xyz', 'sql', 'sql', 2324234235, 'sql']

# %%
l2.insert(1,"r language")   #inserts "r language" at index 1.

# %%
l2
# Out:
# ['abc', 'r language', 'xyz', 'sql', 'sql', 2324234235, 'sql']

# %%
l2.insert(2,"deep learning")

# %%
l2
# Out:
# ['abc', 'r language', 'deep learning', 'xyz', 'sql', 'sql', 2324234235, 'sql']

# %%
l2.pop(2)
# Out:
# 'deep learning'

# %%
l2
# Out:
# ['abc', 'r language', 'xyz', 'sql', 'sql', 2324234235, 'sql']

# %%
l2.insert(3,[2,3,5,7])    #inserts new list [2,3,5,7] at index 3.

# %%
l2
# Out:
# ['abc', 'r language', 'xyz', [2, 3, 5, 7], 'sql', 'sql', 2324234235, 'sql']

# %%
l2.reverse()

# %%
l2
# Out:
# ['sql', 2324234235, 'sql', 'sql', [2, 3, 5, 7], 'xyz', 'r language', 'abc']

# %%
l2
# Out:
# ['sql', 2324234235, 'sql', 'sql', [2, 3, 5, 7], 'xyz', 'r language', 'abc']

# %%
l2[4][2]   #returns value from index 2 inside nested list at index 4.
# Out:
# 5

# %%
l2.count('xyz')     #counts how many times 'xyz' appears in list.
# Out:
# 1

# %%
l2.count('wrt')
# Out:
# 0

# %%
l2.append([3,4,5,6])    #adds list [3,4,5,6] at the end of l2.

# %%
l2
# Out:
# ['sql',
#  2324234235,
#  'sql',
#  'sql',
#  [2, 3, 5, 7],
#  'xyz',
#  'r language',
#  'abc',
#  [3, 4, 5, 6]]

# %%
l2.extend(['devops','aws','azure'])  #adds multiple elements 'devops', 'aws', 'azure' at the end of l2. extend() is an inbuilt list function in Python.
                                    #extend() adds multiple elements at the end of list.
                                    #append() adds one item at the end of list.

# %%
l2
# Out:
# ['sql',
#  2324234235,
#  'sql',
#  'sql',
#  [2, 3, 5, 7],
#  'xyz',
#  'r language',
#  'abc',
#  [3, 4, 5, 6],
#  'devops',
#  'aws',
#  'azure']

# %%
l2.reverse()

# %%
l2
# Out:
# ['azure',
#  'aws',
#  'devops',
#  [3, 4, 5, 6],
#  'abc',
#  'r language',
#  'deep learning',
#  [2, 3, 5, 7],
#  'r language',
#  'xyz',
#  'sql',
#  2324234235]

# %%
l1+list('mlrt')   #list('mlrt') converts string into character list, and + joins both lists.
# Out:
# [242353456456547567686787, 'ravi', 4445454, 'm', 'l', 'r', 't']

# %%
l1+['mlrt']  #l1 + ['mlrt'] joins two lists, so 'mlrt' is added as one list item.
# Out:
# [242353456456547567686787, 'ravi', 4445454, 'mlrt']

# %%
list('mlrt')  #converts string into character list.
# Out:
# ['m', 'l', 'r', 't']

# %%
['mlrt']    #converts string into character list.
# Out:
# ['mlrt']
